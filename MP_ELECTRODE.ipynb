# %% [markdown]
# <a href="https://colab.research.google.com/github/Sham-Sandy/CIF/blob/main/MP_ELECTRODE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install emmet-core
# !pip install mp-api
# !pip install mp-api --upgrade
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.5/51.5 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.4/561.4 kB 30.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 69.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.3/332.3 kB 20.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 32.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.1/739.1 kB 39.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.0/99.0 kB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 kB 10.9 MB/s eta 0:00:00
# ...

# %%
from mp_api.client import MPRester  # Import MPRester from the mp_api.client submodule

mpr = MPRester(api_key="BxQMskLUGXMbrKWP6o33GGRH1T3Dquti")

with mpr as client:  # Use the context manager to ensure proper resource management
    docs = client.insertion_electrodes.search(
        fields=['battery_type', 'battery_id', 'thermo_type', 'battery_formula', 'working_ion', 'num_steps', 'max_voltage_step', 'last_updated', 'framework', 'framework_formula', 'elements', 'nelements', 'chemsys', 'formula_anonymous', 'warnings', 'formula_charge', 'formula_discharge', 'max_delta_volume', 'average_voltage', 'capacity_grav', 'capacity_vol', 'energy_grav', 'energy_vol', 'fracA_charge', 'fracA_discharge', 'stability_charge', 'stability_discharge', 'id_charge', 'id_discharge', 'host_structure', 'adj_pairs', 'material_ids', 'entries_composition_summary', 'electrode_object']  # Request specific fields
    )
    print(len(docs))
# Out:
# <ipython-input-4-6d172ff2cf80>:6: DeprecationWarning: Accessing insertion_electrodes data through MPRester.insertion_electrodes is deprecated. Please use MPRester.materials.insertion_electrodes instead.
#   docs = client.insertion_electrodes.search(
# /usr/local/lib/python3.11/dist-packages/mp_api/client/core/client.py:526: UserWarning: Ignoring `fields` argument: All fields are always included when no query is provided.
#   warnings.warn(
# Retrieving InsertionElectrodeDoc documents:   0%|          | 0/4678 [00:00<?, ?it/s]
# 4678

# %%
for doc in docs:
        battery_type = doc.battery_type
        battery_id = doc.battery_id
        thermo_type = doc.thermo_type
        battery_formula = doc.battery_formula
        working_ion = doc.working_ion
        num_steps = doc.num_steps
        max_voltage_step = doc.max_voltage_step
        elements = doc.elements
        nelements = doc.nelements
        chemsys = doc.chemsys
        formula_anonymous = doc.formula_anonymous
        average_voltage = doc.average_voltage

        print(f"Material IDs: {material_ids}, Battery ID: {battery_id}, Average Voltage: {average_voltage}, Formula anonymous: {formula_anonymous}")
        print(f"Battery Type: {battery_type}, Thermo Type: {thermo_type}, Battery Formula: {battery_formula}")
        print(f"Working Ion: {working_ion}, Num Steps: {num_steps}, Max Voltage Step: {max_voltage_step}")
        print(f"Elements: {elements}, Nelements: {nelements}, ChemSys: {chemsys}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Material IDs: [MPID(mp-997084), MPID(mp-1236284)], Battery ID: mp-769612_Li, Average Voltage: 3.196130994999995, Formula anonymous: AB3C6D24
# Battery Type: insertion, Thermo Type: None, Battery Formula: Li0-6Mn3P6WO24
# Working Ion: Li, Num Steps: 1, Max Voltage Step: 0.0
# Elements: [Element Mn, Element P, Element W, Element O], Nelements: 4, ChemSys: Mn-O-P-W
# Material IDs: [MPID(mp-997084), MPID(mp-1236284)], Battery ID: mp-770152_Li, Average Voltage: 3.532282031666663, Formula anonymous: A2B3C3D16
# Battery Type: insertion, Thermo Type: None, Battery Formula: Li0-4Ti2Mn3Cr3O16
# Working Ion: Li, Num Steps: 1, Max Voltage Step: 0.0
# Elements: [Element Ti, Element Mn, Element Cr, Element O], Nelements: 4, ChemSys: Cr-Mn-O-Ti
# Material IDs: [MPID(mp-997084), MPID(mp-1236284)], Battery ID: mp-770369_Li, Average Voltage: 3.958698746666665, Formula anonymous: ABCD7
# ...

# %%
# !pip install mp_api --upgrade

# %%
import warnings
from collections import defaultdict
from typing import List, Optional, Tuple, Union

from copy import deepcopy
import numpy as np
import pandas as pd

list_of_dict = []

# Iterate through 'docs' and extract relevant data into dictionaries
for doc in docs:
    # Create a dictionary for each document
    doc_dict = {
        'battery_type': doc.battery_type,
        'battery_id': doc.battery_id,
        'thermo_type': doc.thermo_type,
        'battery_formula': doc.battery_formula,
        'working_ion': doc.working_ion,
        'num_steps': doc.num_steps,
        'max_voltage_step': doc.max_voltage_step,
        'elements': doc.elements,
        'nelements': doc.nelements,
        'chemsys': doc.chemsys,
        'formula_anonymous': doc.formula_anonymous,
        'average_voltage': doc.average_voltage,
        # Add other fields as needed
    }
    # Append the dictionary to the list
    list_of_dict.append(doc_dict)

# Create a DataFrame from the list of dictionaries
df = pd.DataFrame(list_of_dict)

# Define the path for the pickle file
MP_PKL = "materials_data.pkl"  # Replace with your desired file path

# Now you can pickle the DataFrame
df.to_pickle(MP_PKL)

print("materials saved")
# Out:
# materials saved

# %%
import pandas as pd

# Load the DataFrame from the pickle file
MP_PKL = "materials_data.pkl"  # Assuming this is the path to your pickle file
df = pd.read_pickle(MP_PKL)

# Convert the DataFrame to a CSV file
df.to_csv("materials_data.csv", index=False)  # index=False to avoid saving the index

print("CSV file created successfully!")
# Out:
# CSV file created successfully!
